# %% [markdown]
# # CRYPTO CURRENCY ML PROJECT

# %%
#lets import important libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
import os
cwd=os.getcwd()
print(cwd)
# Out:
# C:\Users\PC DOCTOR\A_PYTHON PRACTICE\project

# %%
df1=pd.read_csv("C:\\Users\\PC DOCTOR\\A_PYTHON PRACTICE\\project\\COIN\\coin_gecko_2022-03-17.csv")

# %%
df1
# Out:
#                   coin symbol         price     1h    24h     7d  \
# 0              Bitcoin    BTC  40851.380000  0.001  0.000 -0.027
# 1             Ethereum    ETH   2824.420000  0.004  0.029  0.034
# 2               Tether   USDT      1.000000 -0.000  0.000  0.000
# 3                  BNB    BNB    389.610000  0.002  0.016 -0.010
# 4             USD Coin   USDC      0.999739 -0.001  0.000 -0.000
# ..                 ...    ...           ...    ...    ...    ...
# 495            IRISnet   IRIS      0.055426  0.016 -0.003 -0.088
# 496  Circuits of Value  COVAL      0.037961  0.002 -0.012 -0.054
# 497         ARPA Chain   ARPA      0.069003 -0.000  0.008 -0.037
# 498          SuperRare   RARE      0.464613 -0.003  0.014  0.019
# 499         Verus Coin   VRSC      0.999387  0.053  0.061 -0.122
#
#        24h_volume       mkt_cap        date
# 0    2.047612e+10  7.760774e+11  2022-03-17
# 1    1.364041e+10  3.390772e+11  2022-03-17
# 2    4.413140e+10  8.020588e+10  2022-03-17
# ...

# %%
df2=pd.read_csv("C:\\Users\\PC DOCTOR\\A_PYTHON PRACTICE\\project\\COIN\\coin_gecko_2022-03-16.csv")

# %%
df2
# Out:
#            coin symbol         price     1h    24h     7d    24h_volume  \
# 0       Bitcoin    BTC  40859.460000  0.022  0.030  0.055  3.539076e+10
# 1      Ethereum    ETH   2744.410000  0.024  0.034  0.065  1.974870e+10
# 2        Tether   USDT      1.000000 -0.001 -0.001  0.000  5.793497e+10
# 3           BNB    BNB    383.430000  0.018  0.028  0.004  1.395854e+09
# 4      USD Coin   USDC      0.999874 -0.001  0.000 -0.000  3.872274e+09
# ..          ...    ...           ...    ...    ...    ...           ...
# 495  ARPA Chain   ARPA      0.068516  0.028  0.026 -0.008  1.483831e+07
# 496     GuildFi     GF      1.540000  0.005  0.007  0.041  7.298293e+06
# 497    EverRise   RISE      0.000951  0.013  0.081  0.030  4.232180e+05
# 498   SuperRare   RARE      0.458127  0.018  0.029  0.029  1.642138e+07
# 499      Oxygen    OXY      0.325739  0.015  0.001  0.084  4.646240e+05
#
#           mkt_cap        date
# 0    7.709915e+11  2022-03-16
# 1    3.271044e+11  2022-03-16
# ...

# %%
df3 = df2.merge(df1,on='coin',how='outer')
df3
# Out:
#                    coin symbol_x       price_x   1h_x  24h_x   7d_x  \
# 0               Bitcoin      BTC  40859.460000  0.022  0.030  0.055
# 1              Ethereum      ETH   2744.410000  0.024  0.034  0.065
# 2                Tether     USDT      1.000000 -0.001 -0.001  0.000
# 3                   BNB      BNB    383.430000  0.018  0.028  0.004
# 4              USD Coin     USDC      0.999874 -0.001  0.000 -0.000
# ..                  ...      ...           ...    ...    ...    ...
# 501                Blox      NaN           NaN    NaN    NaN    NaN
# 502                MAPS      NaN           NaN    NaN    NaN    NaN
# 503              Netvrk      NaN           NaN    NaN    NaN    NaN
# 504  Loom Network (OLD)      NaN           NaN    NaN    NaN    NaN
# 505          Verus Coin      NaN           NaN    NaN    NaN    NaN
#
#      24h_volume_x     mkt_cap_x      date_x symbol_y       price_y   1h_y  \
# 0    3.539076e+10  7.709915e+11  2022-03-16      BTC  40851.380000  0.001
# ...

# %% [markdown]
# #so,the final merged data we got as df3

# %%
df3
# Out:
#                    coin symbol_x       price_x   1h_x  24h_x   7d_x  \
# 0               Bitcoin      BTC  40859.460000  0.022  0.030  0.055
# 1              Ethereum      ETH   2744.410000  0.024  0.034  0.065
# 2                Tether     USDT      1.000000 -0.001 -0.001  0.000
# 3                   BNB      BNB    383.430000  0.018  0.028  0.004
# 4              USD Coin     USDC      0.999874 -0.001  0.000 -0.000
# ..                  ...      ...           ...    ...    ...    ...
# 501                Blox      NaN           NaN    NaN    NaN    NaN
# 502                MAPS      NaN           NaN    NaN    NaN    NaN
# 503              Netvrk      NaN           NaN    NaN    NaN    NaN
# 504  Loom Network (OLD)      NaN           NaN    NaN    NaN    NaN
# 505          Verus Coin      NaN           NaN    NaN    NaN    NaN
#
#      24h_volume_x     mkt_cap_x      date_x symbol_y       price_y   1h_y  \
# 0    3.539076e+10  7.709915e+11  2022-03-16      BTC  40851.380000  0.001
# ...

# %%
df3.head()
# Out:
#        coin symbol_x       price_x   1h_x  24h_x   7d_x  24h_volume_x  \
# 0   Bitcoin      BTC  40859.460000  0.022  0.030  0.055  3.539076e+10
# 1  Ethereum      ETH   2744.410000  0.024  0.034  0.065  1.974870e+10
# 2    Tether     USDT      1.000000 -0.001 -0.001  0.000  5.793497e+10
# 3       BNB      BNB    383.430000  0.018  0.028  0.004  1.395854e+09
# 4  USD Coin     USDC      0.999874 -0.001  0.000 -0.000  3.872274e+09
#
#       mkt_cap_x      date_x symbol_y       price_y   1h_y  24h_y   7d_y  \
# 0  7.709915e+11  2022-03-16      BTC  40851.380000  0.001  0.000 -0.027
# 1  3.271044e+11  2022-03-16      ETH   2824.420000  0.004  0.029  0.034
# 2  7.996516e+10  2022-03-16     USDT      1.000000 -0.000  0.000  0.000
# 3  6.404382e+10  2022-03-16      BNB    389.610000  0.002  0.016 -0.010
# 4  5.222214e+10  2022-03-16     USDC      0.999739 -0.001  0.000 -0.000
#
#    24h_volume_y     mkt_cap_y      date_y
# 0  2.047612e+10  7.760774e+11  2022-03-17
# ...

# %%
df3.size
# Out:
# 8602

# %%
df3.shape
# Out:
# (506, 17)

# %%
df3.describe()
#statistical value analysis
# Out:
#             price_x        1h_x       24h_x        7d_x  24h_volume_x  \
# count  5.000000e+02  497.000000  497.000000  497.000000  4.970000e+02
# mean   6.527851e+02    0.018746    0.028849    0.039016  3.276644e+08
# std    4.578529e+03    0.013867    0.058065    0.203688  3.182264e+09
# min    1.544000e-09   -0.039000   -0.141000   -0.547000  0.000000e+00
# 25%    1.904625e-01    0.011000    0.004000   -0.020000  1.838591e+06
# 50%    1.085000e+00    0.018000    0.021000    0.006000  8.581305e+06
# 75%    6.925000e+00    0.026000    0.040000    0.049000  4.075655e+07
# max    4.121727e+04    0.086000    0.573000    2.935000  5.793497e+10
#
#           mkt_cap_x       price_y        1h_y       24h_y        7d_y  \
# count  5.000000e+02  5.000000e+02  496.000000  496.000000  495.000000
# mean   3.722677e+09  6.594269e+02    0.000681    0.018615    0.008038
# std    3.784349e+10  4.595355e+03    0.033128    0.060142    0.252549
# ...

# %%
df3.describe(include='all') 
#include all the parameter for statisrical analysis
# Out:
#            coin symbol_x       price_x        1h_x       24h_x        7d_x  \
# count       506      500  5.000000e+02  497.000000  497.000000  497.000000
# unique      506      497           NaN         NaN         NaN         NaN
# top     Bitcoin     TIME           NaN         NaN         NaN         NaN
# freq          1        2           NaN         NaN         NaN         NaN
# mean        NaN      NaN  6.527851e+02    0.018746    0.028849    0.039016
# std         NaN      NaN  4.578529e+03    0.013867    0.058065    0.203688
# min         NaN      NaN  1.544000e-09   -0.039000   -0.141000   -0.547000
# 25%         NaN      NaN  1.904625e-01    0.011000    0.004000   -0.020000
# 50%         NaN      NaN  1.085000e+00    0.018000    0.021000    0.006000
# 75%         NaN      NaN  6.925000e+00    0.026000    0.040000    0.049000
# max         NaN      NaN  4.121727e+04    0.086000    0.573000    2.935000
#
# ...

# %%
#quick cheak for null values.
df3.isnull().sum()
# Out:
# coin             0
# symbol_x         6
# price_x          6
# 1h_x             9
# 24h_x            9
# 7d_x             9
# 24h_volume_x     9
# mkt_cap_x        6
# date_x           6
# symbol_y         6
# price_y          6
# 1h_y            10
# 24h_y           10
# 7d_y            11
# 24h_volume_y    10
# mkt_cap_y        6
# date_y           6
# dtype: int64

# %%
#lets cheak for the duplicate value.
df3.duplicated().sum()
# Out:
# 0

# %%
df3.dtypes
# Out:
# coin             object
# symbol_x         object
# price_x         float64
# 1h_x            float64
# 24h_x           float64
# 7d_x            float64
# 24h_volume_x    float64
# mkt_cap_x       float64
# date_x           object
# symbol_y         object
# price_y         float64
# 1h_y            float64
# 24h_y           float64
# 7d_y            float64
# 24h_volume_y    float64
# mkt_cap_y       float64
# date_y           object
# dtype: object

# %%
# finally we have df4.dtypes

# %%
sns.barplot(x='symbol_x',y='24h_x',data=df3)
plt.title('price trend in 24h')
plt.legend
plt.show()

# %%
sns.barplot(x='symbol_y',y='24h_y',data=df3)
plt.title('price trend in 24h')
plt.legend
plt.show()

# %%
# Sort by volume and get top 5
top5_16 = df1.sort_values(by="24h_volume", ascending=False).head(5)
top5_17 = df2[df2['coin'].isin(top5_16['coin'])]  # match coins for fair comparison

coins = top5_16["coin"].tolist()
volume_16 = top5_16["24h_volume"].tolist()
volume_17 = top5_17.set_index("coin").loc[coins]["24h_volume"].tolist()

# Bar positions
x = np.arange(len(coins))
width = 0.35

# Plot
fig, ax = plt.subplots(figsize=(10, 6))
bar1 = ax.bar(x - width/2, volume_16, width, label='March 16')
bar2 = ax.bar(x + width/2, volume_17, width, label='March 17')

# Labels and title
ax.set_xlabel("Coin")
ax.set_ylabel("24h Trading Volume (USD)")
ax.set_title("Top 5 Cryptocurrencies by 24h Volume (Side-by-Side)")
ax.set_xticks(x)
ax.set_xticklabels(coins)
ax.legend()

plt.tight_layout()
plt.show()

# %%
# Combine both dataframes into one for correlation analysis
df1['date'] = pd.to_datetime(df1['date'])
df2['date'] = pd.to_datetime(df2['date'])
combined_df = pd.concat([df1, df2], ignore_index=True)

# Select only numerical columns for correlation
numeric_cols = ['price', '1h', '24h', '7d', '24h_volume', 'mkt_cap']
correlation_matrix = combined_df[numeric_cols].corr()

correlation_matrix
# Out:
#                price        1h       24h        7d  24h_volume   mkt_cap
# price       1.000000  0.001832 -0.005455  0.016843    0.184038  0.366709
# 1h          0.001832  1.000000  0.436889  0.132341   -0.006421  0.003880
# 24h        -0.005455  0.436889  1.000000  0.479752   -0.009329 -0.007842
# 7d          0.016843  0.132341  0.479752  1.000000    0.015566 -0.001126
# 24h_volume  0.184038 -0.006421 -0.009329  0.015566    1.000000  0.599778
# mkt_cap     0.366709  0.003880 -0.007842 -0.001126    0.599778  1.000000

# %%
# Plotting the correlation matrix heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", center=0)
plt.title("Correlation Matrix of Cryptocurrency Features")
plt.tight_layout()
plt.show()

# %%
# Amihud_indicator calculation
# 1. Clean up column names
df3.columns = df3.columns.str.strip()

# 2. Calculate price return between date_x and date_y
df3['price_return'] = (df3['price_y'] - df3['price_x']) / df3['price_x']

# 3. Calculate volume ratio (volume_y / volume_x)
df3['volume_ratio'] = df3['24h_volume_y'] / df3['24h_volume_x']

# 4. Calculate Amihud Illiquidity for each date
# Note: Using absolute % return / volume as proxy
df3['amihud_x'] = np.abs(df3['24h_x']) / df3['24h_volume_x']
df3['amihud_y'] = np.abs(df3['24h_y']) / df3['24h_volume_y']

# 5. Calculate change in Amihud between the two dates
df3['amihud_change'] = df3['amihud_y'] - df3['amihud_x']

# 6. Now print the result
print(df3[['coin', 'price_x', 'price_y', 'price_return', 'volume_ratio', 'amihud_x', 'amihud_y', 'amihud_change']].head())
# Out:
#        coin       price_x       price_y  price_return  volume_ratio  \
# 0   Bitcoin  40859.460000  40851.380000     -0.000198      0.578572
# 1  Ethereum   2744.410000   2824.420000      0.029154      0.690699
# 2    Tether      1.000000      1.000000      0.000000      0.761740
# 3       BNB    383.430000    389.610000      0.016118      1.021134
# 4  USD Coin      0.999874      0.999739     -0.000135      0.921892
#
#        amihud_x      amihud_y  amihud_change
# 0  8.476788e-13  0.000000e+00  -8.476788e-13
# 1  1.721633e-12  2.126036e-12   4.044033e-13
# 2  1.726073e-14  0.000000e+00  -1.726073e-14
# 3  2.005940e-11  1.122528e-11  -8.834123e-12
# 4  0.000000e+00  0.000000e+00   0.000000e+00

# %%
#2 days moving average values
print("so,based on data the moving average values of all crypto are as follows:")
df3['price_ma_2'] = (df3['price_x'] + df3['price_y']) / 2
df3['volume_ma_2'] = (df3['24h_volume_x'] + df3['24h_volume_y']) / 2

print(df3[['coin', 'price_x', 'price_y', 'price_ma_2', '24h_volume_x', '24h_volume_y', 'volume_ma_2']].head())
# Out:
# so,based on data the moving average values of all crypto are as follows:
#        coin       price_x       price_y    price_ma_2  24h_volume_x  \
# 0   Bitcoin  40859.460000  40851.380000  40855.420000  3.539076e+10
# 1  Ethereum   2744.410000   2824.420000   2784.415000  1.974870e+10
# 2    Tether      1.000000      1.000000      1.000000  5.793497e+10
# 3       BNB    383.430000    389.610000    386.520000  1.395854e+09
# 4  USD Coin      0.999874      0.999739      0.999807  3.872274e+09
#
#    24h_volume_y   volume_ma_2
# 0  2.047612e+10  2.793344e+10
# 1  1.364041e+10  1.669455e+10
# 2  4.413140e+10  5.103319e+10
# 3  1.425354e+09  1.410604e+09
# 4  3.569816e+09  3.721045e+09

# %%
#volatility calculation from daily data.
print("so,volatility are as follows:")
# Assuming 'price' is a column in your DataFrame.
returns = df3['price_x'].pct_change()  # Calculate daily returns
volatility = returns.std()  # Standard deviation of returns

print("Volatility:", volatility)
# Out:
# so,volatility are as follows:
# Volatility: 913642449.7094438

# %%
##volatility calculation from daily data.
print("liquidity ratio from daily data is: ")
liquidity_ratio = df3['24h_volume_x'] / df3['mkt_cap_x']
liquidity_ratio
# Out:
# liquidity ratio from daily data is:
# 0      0.045903
# 1      0.060374
# 2      0.724503
# 3      0.021795
# 4      0.074150
#          ...
# 501         NaN
# 502         NaN
# 503         NaN
# 504         NaN
# 505         NaN
# Length: 506, dtype: float64

# %%
df4 = df3.replace([np.inf, -np.inf], np.nan)
df5 = df4.dropna()
df5
# Out:
#                coin symbol_x       price_x   1h_x  24h_x   7d_x  24h_volume_x  \
# 0           Bitcoin      BTC  40859.460000  0.022  0.030  0.055  3.539076e+10
# 1          Ethereum      ETH   2744.410000  0.024  0.034  0.065  1.974870e+10
# 2            Tether     USDT      1.000000 -0.001 -0.001  0.000  5.793497e+10
# 3               BNB      BNB    383.430000  0.018  0.028  0.004  1.395854e+09
# 4          USD Coin     USDC      0.999874 -0.001  0.000 -0.000  3.872274e+09
# ..              ...      ...           ...    ...    ...    ...           ...
# 491  cVault.finance     CORE   6768.400000  0.016  0.031  0.004  2.955130e+05
# 495      ARPA Chain     ARPA      0.068516  0.028  0.026 -0.008  1.483831e+07
# 496         GuildFi       GF      1.540000  0.005  0.007  0.041  7.298293e+06
# 498       SuperRare     RARE      0.458127  0.018  0.029  0.029  1.642138e+07
# 499          Oxygen      OXY      0.325739  0.015  0.001  0.084  4.646240e+05
#
# ...

# %%
df4 = df3.replace([np.inf, -np.inf], np.nan)
df5 = df4.fillna(method='ffill')  # or .fillna(0) or .interpolate()
df5
# Out:
#                    coin symbol_x       price_x   1h_x  24h_x   7d_x  \
# 0               Bitcoin      BTC  40859.460000  0.022  0.030  0.055
# 1              Ethereum      ETH   2744.410000  0.024  0.034  0.065
# 2                Tether     USDT      1.000000 -0.001 -0.001  0.000
# 3                   BNB      BNB    383.430000  0.018  0.028  0.004
# 4              USD Coin     USDC      0.999874 -0.001  0.000 -0.000
# ..                  ...      ...           ...    ...    ...    ...
# 501                Blox      OXY      0.325739  0.015  0.001  0.084
# 502                MAPS      OXY      0.325739  0.015  0.001  0.084
# 503              Netvrk      OXY      0.325739  0.015  0.001  0.084
# 504  Loom Network (OLD)      OXY      0.325739  0.015  0.001  0.084
# 505          Verus Coin      OXY      0.325739  0.015  0.001  0.084
#
#      24h_volume_x     mkt_cap_x      date_x symbol_y  ...  24h_volume_y  \
# 0    3.539076e+10  7.709915e+11  2022-03-16      BTC  ...  2.047612e+10
# ...

# %%
_return = df3['price_x'].pct_change()
target = df3['price_x'].shift(-1)
df = df3.dropna()  # VERY IMPORTANT to align X and y

X = _return
y = target

print(X.shape, y.shape)  # ✅ Now they match
# Out:
# (506,) (506,)

# %%
from statsmodels.tsa.arima.model import ARIMA

# Assuming df5 is a DataFrame that contains a 'price_x' column

# Log-transform to stabilize the variance
log_price = np.log(df5['price_x'])

# Fit the ARIMA model (order=(p,d,q) = (5,1,0) in this case)
model = ARIMA(log_price, order=(5, 1, 0))
model_fit = model.fit()

# Forecast the next 30 time steps
log_forecast = model_fit.forecast(steps=30)

# Convert forecast back to original scale
forecast = np.exp(log_forecast)

# Display or return the forecast
print(forecast)
# Out:
# 506    0.325739
# 507    0.325739
# 508    0.325739
# 509    0.325739
# 510    0.325739
# 511    0.325739
# 512    0.325739
# 513    0.325739
# 514    0.325739
# 515    0.325739
# 516    0.325739
# 517    0.325739
# 518    0.325739
# 519    0.325739
# 520    0.325739
# 521    0.325739
# 522    0.325739
# 523    0.325739
# 524    0.325739
# 525    0.325739
# 526    0.325739
# 527    0.325739
# 528    0.325739
# 529    0.325739
# 530    0.325739
# 531    0.325739
# 532    0.325739
# 533    0.325739
# 534    0.325739
# 535    0.325739
# Name: predicted_mean, dtype: float64

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Feature engineering
df3['return_1d'] = df3['price_x'].pct_change()
df3['rolling_mean'] = df3['price_x'].rolling(7).mean()
df3['rolling_std'] = df3['price_x'].rolling(7).std()
df3['target'] = df3['price_x'].shift(-1)  # Predict next day’s price

# Drop missing values due to rolling and shift operations
df = df3.dropna()

# Define features and target
X = df[['return_1d', 'rolling_mean', 'rolling_std']]
y = df['target']

# Split data (no shuffle for time series)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Model training
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Prediction and evaluation
y_pred = model.predict(X_test)
rmse = mean_squared_error(y_test, y_pred, squared=False)
print("RMSE:", rmse)
# Out:
# RMSE: 4216.20789308802

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import mean_squared_error
from scipy.stats import randint

# Define hyperparameter distributions
param_dist = {
    'n_estimators': randint(50, 300),
    'max_depth': randint(5, 50),
    'min_samples_split': randint(2, 10),
    'min_samples_leaf': randint(1, 5),
    'max_features': ['auto', 'sqrt', 'log2']
}

# Set up the RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=RandomForestRegressor(random_state=42),
    param_distributions=param_dist,
    n_iter=50,             # Number of combinations to try
    cv=3,                  # 3-fold cross-validation
    n_jobs=-1,             # Use all CPU cores
    scoring='neg_root_mean_squared_error',
    random_state=42
)

# Fit the random search model
random_search.fit(X_train, y_train)

# Best parameters and score
print("Best Parameters:", random_search.best_params_)
print("Best RMSE (CV, negative):", random_search.best_score_)
# Out:
# Best Parameters: {'max_depth': 35, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 7, 'n_estimators': 264}
# Best RMSE (CV, negative): -4456.50824452006

# %%
# Train model using the best hyperparameters
best_model = RandomForestRegressor(**random_search.best_params_, random_state=42)
best_model.fit(X_train, y_train)

# Predict on test set
y_pred = best_model.predict(X_test)
rmse = mean_squared_error(y_test, y_pred, squared=False)
print("Final RMSE on Test Set:", rmse)
# Out:
# Final RMSE on Test Set: 1028.4626009378928

# %%
#Deployment train model using FLASK
import joblib

# Save the trained model
joblib.dump(best_model, 'crypto_rf_model.pkl')
from flask import Flask, request, jsonify
import joblib
import numpy as np

# Load the trained model
model = joblib.load('crypto_rf_model.pkl')

app = Flask(__name__)

@app.route('/')
def home():
    return "Crypto Price Prediction Model is running!"

@app.route('/predict', methods=['POST'])
def predict():
    data = request.get_json(force=True)

    # Example input: {"return_1d": 0.01, "rolling_mean": 25000, "rolling_std": 300}
    features = np.array([[data['return_1d'], data['rolling_mean'], data['rolling_std']]])
    
    prediction = model.predict(features)[0]

    return jsonify({'predicted_price': prediction})

if __name__ == '__main__':
    app.run(debug=True)

import requests

url = 'http://127.0.0.1:5000/predict'
data = {
    'return_1d': 0.01,
    'rolling_mean': 25000,
    'rolling_std': 300
}

response = requests.post(url, json=data)
print(response.json())

python_app.py

# Open a browser and go to: http://127.0.0.1:5000/
# You should see: "Crypto Price Prediction Model is running!"
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with watchdog (windowsapi)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %%
######################################################################################################################################
